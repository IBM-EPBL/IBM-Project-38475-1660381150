# %% [markdown]
# **Problem Statement: Abalone Age Prediction**
#
# Description:- Predicting the age of abalone from physical measurements. The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task. Other measurements, which are easier to obtain, are used to predict age. Further information, such as weather patterns and location (hence food availability) may be required to solve the problem.

# %% [markdown]
# Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Load the dataset

# %%
import pandas as pd
d=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/abalone.csv')

# %% [markdown]
# Univariate Analysis

# %%
d.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
d.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
d.shape
# Out:
# (4177, 9)

# %%
d.info
# Out:
# <bound method DataFrame.info of      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# ...

# %%
d.head(100)
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    M   0.455     0.365   0.095        0.5140          0.2245
# 1    M   0.350     0.265   0.090        0.2255          0.0995
# 2    F   0.530     0.420   0.135        0.6770          0.2565
# 3    M   0.440     0.365   0.125        0.5160          0.2155
# 4    I   0.330     0.255   0.080        0.2050          0.0895
# ..  ..     ...       ...     ...           ...             ...
# 95   M   0.665     0.535   0.195        1.6060          0.5755
# 96   M   0.535     0.435   0.150        0.7250          0.2690
# 97   M   0.470     0.375   0.130        0.5230          0.2140
# 98   M   0.470     0.370   0.130        0.5225          0.2010
# 99   F   0.475     0.375   0.125        0.5785          0.2775
#
#     Viscera weight  Shell weight  Rings
# 0           0.1010         0.150     15
# 1           0.0485         0.070      7
# 2           0.1415         0.210      9
# 3           0.1140         0.155     10
# ...

# %% [markdown]
# # Perform Below Visualizations.
#  ∙ Univariate Analysis
# ∙ Bi-Variate Analysis
# ∙ Multi-Variate Analysis

# %% [markdown]
# ∙ Univariate Analysis

# %%
sns.boxplot(d['Length'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(d['Shucked weight'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.displot('Whole weight')

# %%
sns.displot(d['Whole weight'])

# %%
d.Sex.value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
sns.displot(d['Height'])

# %%
sns.displot(d['Rings'])

# %% [markdown]
# Bi-Variate Analysis

# %%
sns.barplot(d['Sex'], d['Rings'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(d['Height'].head(),d['Rings'].head())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(d['Sex'].head(),d['Whole weight'].head())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(d['Sex'],d['Height'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(d['Whole weight'],d['Diameter'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot('Diameter','Rings',hue='Sex',data=d.head())
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.barplot(d['Sex'], d['Rings'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Multi-Variate Analysis

# %%
sns.scatterplot(d['Shell weight'],d['Whole weight'],d['Shucked weight'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pairplot(d,'Rings')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.pairplot(d,'Sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
#  Perform descriptive statistics on the dataset.

# %%
d.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length            0.523992
# Diameter          0.407881
# Height            0.139516
# Whole weight      0.828742
# Shucked weight    0.359367
# Viscera weight    0.180594
# Shell weight      0.238831
# Rings             9.933684
# dtype: float64

# %%
d.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length            0.5450
# Diameter          0.4250
# Height            0.1400
# Whole weight      0.7995
# Shucked weight    0.3360
# Viscera weight    0.1710
# Shell weight      0.2340
# Rings             9.0000
# dtype: float64

# %%
d.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
d.mode()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    M   0.550      0.45    0.15        0.2225           0.175
# 1  NaN   0.625       NaN     NaN           NaN             NaN
#
#    Viscera weight  Shell weight  Rings
# 0          0.1715         0.275    9.0
# 1             NaN           NaN    NaN

# %%
d.var()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Length             0.014422
# Diameter           0.009849
# Height             0.001750
# Whole weight       0.240481
# Shucked weight     0.049268
# Viscera weight     0.012015
# Shell weight       0.019377
# Rings             10.395266
# dtype: float64

# %%
d.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
d.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %% [markdown]
# Check for Missing values and deal with them.

# %%
d.isnull().any()
# Out:
# Sex               False
# Length            False
# Diameter          False
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# dtype: bool

# %%
d.isnull()
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# ...

# %%
 d.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
d.isna()
# Out:
#         Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0     False   False     False   False         False           False
# 1     False   False     False   False         False           False
# 2     False   False     False   False         False           False
# 3     False   False     False   False         False           False
# 4     False   False     False   False         False           False
# ...     ...     ...       ...     ...           ...             ...
# 4172  False   False     False   False         False           False
# 4173  False   False     False   False         False           False
# 4174  False   False     False   False         False           False
# 4175  False   False     False   False         False           False
# 4176  False   False     False   False         False           False
#
#       Viscera weight  Shell weight  Rings
# 0              False         False  False
# 1              False         False  False
# ...

# %%
d.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# Find the outliers and replace them outliers

# %%
sns.boxplot(d['Rings'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(d['Diameter'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(d.Length)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(d['Height'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Check for Categorical columns and perform encoding.

# %%
d.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter as count

# %%
la=LabelEncoder()

# %%
d.Sex=la.fit_transform(d.Sex)

# %%
d.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
count(d['Sex'])
# Out:
# Counter({2: 1528, 0: 1307, 1: 1342})

# %%
d['Sex'].unique()
# Out:
# array([2, 0, 1])

# %% [markdown]
# Split the data into dependent and independent variables.

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   int64
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(2)
# memory usage: 293.8 KB

# %%
z=d.Sex

# %%
z.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    2
# 4    1
# Name: Sex, dtype: int64

# %% [markdown]
# Scale the independent variables

# %%
from sklearn.preprocessing import scale 
from sklearn.preprocessing import MinMaxScaler

# %%
x = scale(d)
x
# Out:
# array([[ 1.15198011, -0.57455813, -0.43214879, ..., -0.72621157,
#         -0.63821689,  1.57154357],
#        [ 1.15198011, -1.44898585, -1.439929  , ..., -1.20522124,
#         -1.21298732, -0.91001299],
#        [-1.28068972,  0.05003309,  0.12213032, ..., -0.35668983,
#         -0.20713907, -0.28962385],
#        ...,
#        [ 1.15198011,  0.6329849 ,  0.67640943, ...,  0.97541324,
#          0.49695471, -0.28962385],
#        [-1.28068972,  0.84118198,  0.77718745, ...,  0.73362741,
#          0.41073914,  0.02057072],
#        [ 1.15198011,  1.54905203,  1.48263359, ...,  1.78744868,
#          1.84048058,  0.64095986]])

# %%
sc=MinMaxScaler()
xsc=pd.DataFrame(sc.fit_transform(d),columns=d.columns)
xsc.head()
# Out:
#    Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0  1.0  0.513514  0.521008  0.084071      0.181335        0.150303
# 1  1.0  0.371622  0.352941  0.079646      0.079157        0.066241
# 2  0.0  0.614865  0.613445  0.119469      0.239065        0.171822
# 3  1.0  0.493243  0.521008  0.110619      0.182044        0.144250
# 4  0.5  0.344595  0.336134  0.070796      0.071897        0.059516
#
#    Viscera weight  Shell weight     Rings
# 0        0.132324      0.147982  0.500000
# 1        0.063199      0.068261  0.214286
# 2        0.185648      0.207773  0.285714
# 3        0.149440      0.152965  0.321429
# 4        0.051350      0.053313  0.214286

# %% [markdown]
# Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
y=d
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
X_train
# Out:
# array([[ 1.15198011,  0.79954256,  1.0291325 , ...,  0.52833755,
#          1.0860944 ,  0.02057072],
#        [-0.0643548 , -1.49062526, -1.54070702, ..., -1.31014717,
#         -1.35667992, -1.53040213],
#        [-0.0643548 , -1.24078877, -1.33915098, ..., -1.15047728,
#         -1.24172584, -0.91001299],
#        ...,
#        [ 1.15198011,  0.59134549,  0.42446438, ...,  0.23636976,
#          0.10539235,  0.02057072],
#        [-1.28068972,  0.84118198,  0.82757646, ...,  0.51008957,
#          0.57239333, -0.28962385],
#        [-0.0643548 , -0.94931287, -0.83526087, ..., -0.96343541,
#         -0.99026378, -0.59981842]])

# %%
y_test
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 668     2   0.550     0.425   0.155        0.9175          0.2775
# 1580    1   0.500     0.400   0.120        0.6160          0.2610
# 3784    2   0.620     0.480   0.155        1.2555          0.5270
# 463     1   0.220     0.165   0.055        0.0545          0.0215
# 2615    2   0.645     0.500   0.175        1.5105          0.6735
# ...   ...     ...       ...     ...           ...             ...
# 1052    2   0.765     0.600   0.220        2.3020          1.0070
# 3439    1   0.440     0.350   0.125        0.4560          0.2100
# 1174    0   0.635     0.495   0.015        1.1565          0.5115
# 2210    2   0.660     0.505   0.200        1.6305          0.4865
# 2408    1   0.620     0.485   0.170        1.2080          0.4805
#
#       Viscera weight  Shell weight  Rings
# 668           0.2430        0.3350     13
# 1580          0.1430        0.1935      8
# 3784          0.3740        0.3175     11
# ...

# %%
X_test
# Out:
# array([[ 1.15198011,  0.21659075,  0.17251933, ...,  0.56939553,
#          0.69093973,  0.95115443],
#        [-0.0643548 , -0.1998034 , -0.07942572, ..., -0.34300384,
#         -0.32568547, -0.59981842],
#        [ 1.15198011,  0.79954256,  0.72679844, ...,  1.7646387 ,
#          0.56520869,  0.33076529],
#        ...,
#        [-1.28068972,  0.92446081,  0.87796547, ...,  1.16245511,
#          0.35685441, -0.28962385],
#        [ 1.15198011,  1.13265788,  0.97874349, ...,  1.06209118,
#          2.66671307,  2.50212727],
#        [-0.0643548 ,  0.79954256,  0.77718745, ...,  1.13052114,
#          0.65501657,  1.57154357]])

# %%
y_train
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1376    2   0.620     0.510   0.175        1.2815          0.5715
# 1225    1   0.345     0.255   0.085        0.2005          0.1050
# 2722    1   0.375     0.275   0.095        0.2295          0.0950
# 3387    2   0.545     0.410   0.145        0.8730          0.3035
# 2773    0   0.580     0.465   0.145        0.9865          0.4700
# ...   ...     ...       ...     ...           ...             ...
# 1033    2   0.650     0.525   0.185        1.6220          0.6645
# 3264    0   0.655     0.500   0.140        1.1705          0.5405
# 1653    2   0.595     0.450   0.145        0.9590          0.4630
# 2607    0   0.625     0.490   0.165        1.1270          0.4770
# 2732    1   0.410     0.325   0.110        0.3260          0.1325
#
#       Viscera weight  Shell weight  Rings
# 1376          0.2385        0.3900     10
# 1225          0.0370        0.0500      5
# 2722          0.0545        0.0660      7
# ...

# %% [markdown]
# Build the Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state =42)

# %%
ml = LinearRegression()

ml.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Train the Model

# %%
from sklearn.linear_model import LinearRegression
ml = LinearRegression()

ml.fit(x_train,y_train)
Y_predict_train = ml.predict(x_train)
Y_predict_train
# Out:
# array([[-5.55111512e-15,  6.15000000e-01,  4.55000000e-01, ...,
#          2.63000000e-01,  2.74000000e-01,  9.00000000e+00],
#        [-4.66293670e-15,  5.15000000e-01,  3.95000000e-01, ...,
#          1.25500000e-01,  2.20000000e-01,  1.20000000e+01],
#        [ 2.00000000e+00,  6.60000000e-01,  5.30000000e-01, ...,
#          3.50500000e-01,  4.05000000e-01,  1.00000000e+01],
#        ...,
#        [ 2.00000000e+00,  5.10000000e-01,  3.95000000e-01, ...,
#          1.33500000e-01,  1.88000000e-01,  1.10000000e+01],
#        [ 2.00000000e+00,  5.75000000e-01,  4.65000000e-01, ...,
#          2.18500000e-01,  2.35000000e-01,  9.00000000e+00],
#        [-4.88498131e-15,  5.95000000e-01,  4.75000000e-01, ...,
#          2.31000000e-01,  2.71000000e-01,  6.00000000e+00]])

# %% [markdown]
#  Test the Model

# %%
y_predict = ml.predict(x_test)
y_predict
# Out:
# array([[ 2.00000000e+00,  6.05000000e-01,  4.55000000e-01, ...,
#          3.01500000e-01,  3.25000000e-01,  9.00000000e+00],
#        [ 2.00000000e+00,  5.90000000e-01,  4.40000000e-01, ...,
#          2.15000000e-01,  2.45000000e-01,  8.00000000e+00],
#        [-4.66293670e-15,  5.60000000e-01,  4.45000000e-01, ...,
#          2.24500000e-01,  3.35000000e-01,  1.60000000e+01],
#        ...,
#        [ 2.00000000e+00,  6.35000000e-01,  5.10000000e-01, ...,
#          3.18000000e-01,  3.77000000e-01,  8.00000000e+00],
#        [ 2.00000000e+00,  4.60000000e-01,  3.75000000e-01, ...,
#          1.04500000e-01,  2.05000000e-01,  9.00000000e+00],
#        [-5.10702591e-15,  5.30000000e-01,  3.85000000e-01, ...,
#          1.51000000e-01,  1.80000000e-01,  1.00000000e+01]])

# %%
pred=ml.predict(X_test)
pred
# Out:
# array([[ 2.00000000e+00,  5.50000000e-01,  4.25000000e-01, ...,
#          2.43000000e-01,  3.35000000e-01,  1.30000000e+01],
#        [ 1.00000000e+00,  5.00000000e-01,  4.00000000e-01, ...,
#          1.43000000e-01,  1.93500000e-01,  8.00000000e+00],
#        [ 2.00000000e+00,  6.20000000e-01,  4.80000000e-01, ...,
#          3.74000000e-01,  3.17500000e-01,  1.10000000e+01],
#        ...,
#        [-5.32907052e-15,  6.35000000e-01,  4.95000000e-01, ...,
#          3.08000000e-01,  2.88500000e-01,  9.00000000e+00],
#        [ 2.00000000e+00,  6.60000000e-01,  5.05000000e-01, ...,
#          2.97000000e-01,  6.10000000e-01,  1.80000000e+01],
#        [ 1.00000000e+00,  6.20000000e-01,  4.85000000e-01, ...,
#          3.04500000e-01,  3.30000000e-01,  1.50000000e+01]])

# %% [markdown]
#  Measure the performance using Metrics.

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error
import math

# %%
print(math.sqrt(mean_squared_error(y_test, y_predict)))
# Out:
# 1.7155563341733253e-15

# %%
print(math.sqrt(mean_squared_error(y_test, y_predict)))
# Out:
# 1.7155563341733253e-15
